# %%
# %sql

--1. Create the catalog
CREATE CATALOG IF NOT EXISTS student_system;

-- 2. Create the Schema 
CREATE SCHEMA IF NOT EXISTS student_system.attendance;

-- 3. Verify it worked
DESCRIBE SCHEMA student_system.attendance;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>student_system</td></tr><tr><td>Namespace Name</td><td>attendance</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Collation</td><td>UTF8_BINARY</td></tr><tr><td>Location</td><td></td></tr><tr><td>Owner</td><td>david.ramirez@est.iudigital.edu.co</td></tr></tbody></table></div>
